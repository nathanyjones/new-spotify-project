# %%
import pandas as pd
df = pd.read_csv('app_data.csv')

def top_songs(df, feature, n=10):
    """
    Return top n songs ranked by a given feature.
    """

    df = df.copy()

    # Check column exists
    if feature not in df.columns:
        raise ValueError(f"{feature} is not a valid column")

    # Convert to numeric safely
    df[feature] = pd.to_numeric(df[feature], errors='coerce')

    # Drop missing values
    df = df.dropna(subset=[feature])

    # Remove duplicates (important)
    df = df.drop_duplicates(subset=['name', 'artists'])

    # Sort and select top n
    top = df.sort_values(feature, ascending=False).head(n)

    # Return clean output
    return top[['name', 'artists', feature]]

top_songs(df, 'acousticness',)
# Out:
#                                                     name           artists  \
# 4795             Above Chiangmai - 2004 Digital Remaster         Brian Eno
# 25488                                          Nathaniel           OutKast
# 3568        I'll Keep It with Mine - Witmark Demo - 1964         Bob Dylan
# 7735   Sonata No.14 in C#m (Moonlight Sonata) - 2006 ...      Depeche Mode
# 36531                                           H alepou   Various Artists
# 36542                          Kathe spiti ki enas ponos   Various Artists
# 23855                       Indian Summer - Instrumental       Miles Davis
# 11134                   Songbird - Instrumental, Take 10     Fleetwood Mac
# 4803               The Chill Air - 2004 Digital Remaster         Brian Eno
# 5594                                            Il pleut  Charles Aznavour
#
#        acousticness
# 4795          0.996
# 25488         0.996
# 3568          0.996
# 7735          0.995
# 36531         0.995
# 36542         0.995
# 23855         0.995
# 11134         0.995
# 4803          0.995
# 5594          0.995

# %%
def feature_trend(df, feature):
    """
    Average feature value per year.
    """

    df = df.copy()
    df[feature] = pd.to_numeric(df[feature], errors='coerce')

    return df.groupby('year')[feature].mean().reset_index()

feature_trend(df, 'acousticness')
# Out:
#     year  acousticness
# 0   1925      0.946500
# 1   1927      0.629000
# 2   1928      0.771000
# 3   1935      0.947000
# 4   1936      0.734500
# ..   ...           ...
# 84  2016      0.206476
# 85  2017      0.193828
# 86  2018      0.196874
# 87  2019      0.224832
# 88  2020      0.225151
#
# [89 rows x 2 columns]

# %%
import numpy as np

def artist_variability(df):
    """
    Measure how diverse an artist's music is.
    """

    features = ['duration_s', 'energy', 'acousticness', 'tempo', 'valence']

    grouped = df.groupby('artists')[features].std()

    grouped['overall_variability'] = grouped.mean(axis=1)

    return grouped.sort_values('overall_variability', ascending=False)

artist_variability(df)
# Out:
#                           duration_s    energy  acousticness      tempo  \
# artists
# Brian Eno                 359.483517  0.296403      0.351223  31.453333
# The Allman Brothers Band  302.908237  0.156712      0.219809  27.794348
# Miles Davis               268.362041  0.215889      0.276226  28.862287
# Yes                       261.687506  0.209997      0.265992  28.938271
# Charles Mingus            236.651133  0.176246      0.261968  32.033338
# ...                              ...       ...           ...        ...
# Lester Flatt               19.495827  0.148695      0.229808  28.368341
# Flatt & Scruggs            18.744817  0.205512      0.262294  23.007582
# Lefty Frizzell             17.453436  0.112860      0.151130  23.146820
# Selena Gomez               21.792636  0.177973      0.201815  18.494957
# La Sonora Matancera        14.404527  0.150754      0.157738  20.864652
#
#                            valence  overall_variability
# artists
# Brian Eno                 0.292450            78.375385
# The Allman Brothers Band  0.190751            66.253972
# Miles Davis               0.236480            59.590585
# Yes                       0.218487            58.264051
# Charles Mingus            0.202010            53.864939
# ...                            ...                  ...
# Lester Flatt              0.177547             9.684044
# Flatt & Scruggs           0.158697             8.475781
# Lefty Frizzell            0.176321             8.208113
# Selena Gomez              0.167944             8.167065
# La Sonora Matancera       0.164828             7.148500
#
# [429 rows x 6 columns]

# %%
import pandas as pd

def artist_variability(df, artist):
    """
    Measure how diverse a specific artist's music is.
    """

    features = ['duration_s', 'energy', 'acousticness', 'tempo', 'valence']

    # Filter to one artist
    df_artist = df[df['artists'] == artist].copy()

    if df_artist.empty:
        raise ValueError("Artist not found in dataset")

    # Ensure numeric
    for col in features:
        df_artist[col] = pd.to_numeric(df_artist[col], errors='coerce')

    df_artist = df_artist.dropna(subset=features)

    # Compute standard deviation per feature
    variability = df_artist[features].std().to_frame().T

    # Add overall score
    variability['overall_variability'] = variability.mean(axis=1)

    return variability

song_variability(df, artist= 'Taylor Swift')
# Out:
#    duration_s    energy  acousticness      tempo  valence  overall_variability
# 0    39.71242  0.177043       0.26034  32.661667   0.1984            14.601974

# %%
def artist_summary(df, artist):

    df = df[df['artists'] == artist]

    return df.describe()[['duration_s', 'energy', 'acousticness', 'tempo']]

artist_summary(df, 'Taylor Swift')
# Out:
#        duration_s      energy  acousticness       tempo
# count  139.000000  139.000000    139.000000  139.000000
# mean   236.487619    0.619676      0.203568  125.125655
# std     39.712420    0.177043      0.260340   32.661667
# min    150.440000    0.118000      0.000197   68.534000
# 25%    211.893000    0.484000      0.021450   96.504000
# 50%    234.147000    0.658000      0.082600  121.956000
# 75%    246.360000    0.752000      0.252000  148.967500
# max    403.920000    0.950000      0.971000  207.476000

# %%
def feature_correlations(df):
    """
    Return correlation matrix for audio features.
    """

    features = ['duration_s', 'energy', 'acousticness', 'tempo', 'valence']

    return df[features].corr()

feature_correlations(df)
# Out:
#               duration_s    energy  acousticness     tempo   valence
# duration_s      1.000000  0.074062     -0.137815 -0.016814 -0.187444
# energy          0.074062  1.000000     -0.672449  0.175031  0.326618
# acousticness   -0.137815 -0.672449      1.000000 -0.127878 -0.139497
# tempo          -0.016814  0.175031     -0.127878  1.000000  0.103467
# valence        -0.187444  0.326618     -0.139497  0.103467  1.000000
